# %%
import pandas as pd
import numpy as np

# %%
with open('batting2022.csv') as f:
    print(f)
# Out:
# <_io.TextIOWrapper name='batting2022.csv' mode='r' encoding='UTF-8'>

# %%
df = pd.read_csv("batting2022.csv", encoding='ISO-8859-1')
df_team = pd.read_csv("teamstats2022.csv", encoding='ISO-8859-1')
df_team_season = pd.read_csv("teamseasonstats2022.csv", encoding='ISO-8859-1')
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#       Rk             Name  Age   Tm   Lg    G   PA   AB   R   H  2B  3B  HR  \
# 0      1       CJÊAbrams*   21  TOT   NL   90  302  284  33  70  12   2   2
# 1      2       CJÊAbrams*   21  SDP   NL   46  139  125  16  29   5   0   2
# 2      3       CJÊAbrams*   21  WSN   NL   44  163  159  17  41   7   2   0
# 3      4     AlbertÊAbreu   26  TOT   AL    1    0    0   0   0   0   0   0
# 4      5     AlbertÊAbreu   26  KCR   AL    1    0    0   0   0   0   0   0
# ..   ...              ...  ...  ...  ...  ...  ...  ...  ..  ..  ..  ..  ..
# 982  983      SebyÊZavala   28  CHW   AL   61  205  178  22  48  14   0   2
# 983  984  BradleyÊZimmer*   29  TOT  MLB  109  117  105  18  13   5   0   2
# 984  985  BradleyÊZimmer*   29  TOR   AL  100  101   89  14   9   4   0   2
# 985  986  BradleyÊZimmer*   29  PHI   NL    9   16   16   4   4   1   0   0
# 986  987      MikeÊZunino   31  TBR   AL   36  123  115   7  17   3   0   5
#
# ...

# %%
df.shape
# Out:
# (987, 31)

# %%
df.describe()
# Out:
#                Rk         Age           G          PA          AB           R  \
# count  987.000000  987.000000  987.000000  987.000000  987.000000  987.000000
# mean   494.000000   28.072948   57.100304  204.520770  183.600811   23.295846
# std    285.066659    3.591565   51.063746  207.323493  185.391901   26.185320
# min      1.000000   20.000000    1.000000    0.000000    0.000000    0.000000
# 25%    247.500000   26.000000    9.000000   21.000000   18.000000    2.000000
# 50%    494.000000   28.000000   44.000000  131.000000  120.000000   14.000000
# 75%    740.500000   31.000000  100.000000  354.500000  323.500000   38.000000
# max    987.000000   42.000000  162.000000  724.000000  657.000000  133.000000
#
#                 H          2B          3B          HR         RBI          SB  \
# count  987.000000  987.000000  987.000000  987.000000  987.000000  987.000000
# mean    44.260385    8.845998    0.723404    5.789260   22.144883    2.755826
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 987 entries, 0 to 986
# Data columns (total 31 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rk               987 non-null    int64
#  1   Name             987 non-null    object
#  2   Age              987 non-null    int64
#  3   Tm               987 non-null    object
#  4   Lg               987 non-null    object
#  5   G                987 non-null    int64
#  6   PA               987 non-null    int64
#  7   AB               987 non-null    int64
#  8   R                987 non-null    int64
#  9   H                987 non-null    int64
#  10  2B               987 non-null    int64
#  11  3B               987 non-null    int64
#  12  HR               987 non-null    int64
#  13  RBI              987 non-null    int64
#  14  SB               987 non-null    int64
#  15  CS               987 non-null    int64
#  16  BB               987 non-null    int64
# ...

# %%
df = df.drop(["Name-additional"], axis=1)

# %%
df
# Out:
#       Rk             Name  Age   Tm   Lg    G   PA   AB   R   H  2B  3B  HR  \
# 0      1       CJÊAbrams*   21  TOT   NL   90  302  284  33  70  12   2   2
# 1      2       CJÊAbrams*   21  SDP   NL   46  139  125  16  29   5   0   2
# 2      3       CJÊAbrams*   21  WSN   NL   44  163  159  17  41   7   2   0
# 3      4     AlbertÊAbreu   26  TOT   AL    1    0    0   0   0   0   0   0
# 4      5     AlbertÊAbreu   26  KCR   AL    1    0    0   0   0   0   0   0
# ..   ...              ...  ...  ...  ...  ...  ...  ...  ..  ..  ..  ..  ..
# 982  983      SebyÊZavala   28  CHW   AL   61  205  178  22  48  14   0   2
# 983  984  BradleyÊZimmer*   29  TOT  MLB  109  117  105  18  13   5   0   2
# 984  985  BradleyÊZimmer*   29  TOR   AL  100  101   89  14   9   4   0   2
# 985  986  BradleyÊZimmer*   29  PHI   NL    9   16   16   4   4   1   0   0
# 986  987      MikeÊZunino   31  TBR   AL   36  123  115   7  17   3   0   5
#
# ...

# %%
df_team
# Out:
#                     ï»¿Tm  #Bat  BatAge   R/G     G      PA      AB      R  \
# 0    Arizona Diamondbacks    57    26.5  4.33   162    6027    5351    702
# 1          Atlanta Braves    53    27.5  4.87   162    6082    5509    789
# 2       Baltimore Orioles    58    27.0  4.16   162    6049    5429    674
# 3          Boston Red Sox    54    28.8  4.54   162    6144    5539    735
# 4            Chicago Cubs    64    27.9  4.06   162    6072    5425    657
# 5       Chicago White Sox    44    29.3  4.23   162    6123    5611    686
# 6         Cincinnati Reds    66    29.4  4.00   162    5978    5380    648
# 7     Cleveland Guardians    50    25.9  4.31   162    6163    5558    698
# 8        Colorado Rockies    43    29.1  4.31   162    6105    5540    698
# 9          Detroit Tigers    53    27.9  3.44   162    5870    5378    557
# 10         Houston Astros    45    29.3  4.55   162    6054    5409    737
# ...

# %%
df_team_season
# Out:
#     ï»¿Rk                     Tm    W    L   W-L% Strk    R   RA  Rdiff  SOS  \
# 0     1.0    Los Angeles Dodgers  111   51  0.685  W 1  5.2  3.2    2.1 -0.2
# 1     2.0         Houston Astros  106   56  0.654  W 2  4.5  3.2    1.4 -0.1
# 2     3.0         Atlanta Braves  101   61  0.623  L 1  4.9  3.8    1.1 -0.1
# 3     4.0          New York Mets  101   61  0.623  W 3  4.8  3.7    1.0 -0.1
# 4     5.0       New York Yankees   99   63  0.611  L 2  5.0  3.5    1.5  0.0
# 5     6.0    St. Louis Cardinals   93   69  0.574  L 1  4.8  3.9    0.8 -0.3
# 6     7.0    Cleveland Guardians   92   70  0.568  W 2  4.3  3.9    0.4 -0.1
# 7     8.0      Toronto Blue Jays   92   70  0.568  W 1  4.8  4.2    0.6  0.1
# 8     9.0       Seattle Mariners   90   72  0.556  W 3  4.3  3.8    0.4  0.0
# 9    10.0       San Diego Padres   89   73  0.549  L 1  4.4  4.1    0.3  0.0
# 10   11.0  Philadelphia Phillies   87   75  0.537  L 2  4.6  4.2    0.4  0.0
# ...
